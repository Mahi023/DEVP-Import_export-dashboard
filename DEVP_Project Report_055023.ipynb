# %% [markdown]
# # **Data Visualization (Dashboard) with Python using Pandas, Numpy, Matplotlib & Streamlit Libraries**
#
# # 1. Project Information
# * **Student Name: Mahi**
# * **Enrollment Number: 055023**
# * **Data Source** =    **[Imports_Exports_Dataset on Kaggle](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000)**
#
# ---

# %% [markdown]
# # 2. Description of Data

# %% [markdown]
# ## About Dataset
# **Title:** Detailed Imports and Exports Dataset with Comprehensive Transaction Information
#
# **Description:**
#
# This dataset provides detailed information on international trade transactions, capturing both import and export activities. It includes comprehensive data on various aspects of trade, making it a valuable resource for business analysis, economic research, and financial modeling.
#
# **Features:**
#
# * **Transaction_ID:** Unique identifier for each trade transaction.
# * **Country:** Country of origin or destination for the trade.
# * **Product:** Product being traded.
# * **Import_Export:** Indicates whether the transaction is an import or export.
# * **Quantity:** Amount of the product traded.
# * **Value:** Monetary value of the product in USD.
# * **Date:** Date of the transaction.
# * **Category:** Category of the product (e.g., Electronics, Clothing, Machinery).
# * **Port:** Port of entry or departure.
# * **Customs_Code:** Customs or HS code for product classification.
# * **Weight:** Weight of the product in kilograms.
# * **Shipping_Method:** Method used for shipping (e.g., Air, Sea, Land).
# * **Supplier:** Name of the supplier or manufacturer.
# * **Customer:** Name of the customer or recipient.
# * **Invoice_Number:** Unique invoice number for the transaction.
# * **Payment_Terms:** Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
#
#
#
# ***Usage:*** This dataset can be used for various analyses, including:
#
#
# * **Trade Analysis:** Understanding trade patterns and trends.
# * **Economic Research:** Studying the impact of trade on different economies.
# * **Financial Modeling:** Evaluating financial performance and risks associated with trade.
# * **Supply Chain Management:** Analyzing logistics and shipping methods.

# %% [markdown]
# **Data Type**: Panel

# %% [markdown]
# **Variable Types:**
# 1) **Text** - Transaction_ID, Country, Product, Import_Export, Date, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms
# 2) **Number- Integer** - Quantity, Customs_Code, Invoice_Number
# 3) **Number- Decimals** - Value, Weight

# %% [markdown]
# **Data Variable Category:**
# 1. **Index**- Transaction_ID, Customs_Code, Invoice_Number, Product, Supplier, Customer
# 2. **Categorical- Nominal** - Import_Export, Category, Shipping_Method, Payment_Terms, Country
# 3. **Categorical- Ordinal** -
# 4. **Non-Categorical**-  Quantity, Value, Date, Port, Weight

# %% [markdown]
# # 3. Problem Statement
#
# This analysis uses a dataset of import and export data. The aim is to explore, analyze, and visualize this information to find patterns and insights about trade statistics. The process will involve cleaning the data, creating visualizations, and analyzing the results to uncover valuable insights.

# %% [markdown]
# # Objectives
#
# 1. Data Loading and Inspectiont.
# 2. Data Cleaninet.
# 3. Data Sampliion.
# 4. Creating Dashboard.
# 5. Feature Engineetions.
# 6. Insights and Recommendations.

# %% [markdown]
# # 4. Analysis of Data
# ### Analysis of Import and Export Transactions
#
# Our recent analysis shows a balanced trading environment, with imports at **51.2%** and exports at **48.8%**. This indicates a thriving market for both activities. The **electronics** category stands out, featuring the highest transaction values, which suggests strong demand and potential for growth in this sector.
#
# Most transactions prefer **cash on delivery**, highlighting a desire for security in payments. This means businesses should focus on efficient delivery and customer service to enhance trust.
#
# Monthly trends reveal that exports peak in **June** at **$5,800**, but drop to **$4,800** in **August**. Similarly, imports are highest in **August** at **$5,250**, dropping to **$4,600** in **December**. These fluctuations indicate typical seasonal buying patterns.
#
# Overall, the data suggests a healthy trade balance, especially in electronics, with opportunities to strategize around peak trading periods. By aligning operations with these trends, businesses can improve their performance and meet market demands effectively.

# %% [markdown]
# # 5. Observations | Findings

# %% [markdown]
# Cash on delivery is the go-to payment method in countries like Iran and Belarus, where Western payment practices aren't as common. Interestingly, exports tend to dip sharply in February and August. Overall, imports and exports are well balanced, and this balance is consistent across all individual categories.

# %% [markdown]
# # 6. Managerial Insights | Recommendations

# %% [markdown]
# Here are some practical insights for management based on the analysis:
#
# Build Relationships with Key Trade Partners: Focus on countries that show consistently high trade volumes. Strengthening ties with these nations can lead to strategic agreements that boost revenue. Governments might also think about policies that foster ongoing growth with these important partners.
#
# Prioritize Key Product Categories: Some product categories really drive international trade and add significant value. Businesses should concentrate their investments and marketing efforts in these areas to enhance profitability. This might mean improving supply chain efficiency, fine-tuning pricing strategies, or negotiating better terms with suppliers and customers.
#
# Keep an Eye on Seasonal Trends: The data reveals that trade volumes can fluctuate throughout the year, with certain times seeing noticeable increases. By paying attention to these seasonal trends, businesses can better align their operations, manage inventory, and plan logistics to meet demand during peak times, ultimately optimizing profits and improving resource management during slower periods.
#
# Explore Diverse Product Offerings: While it’s smart to focus on top-performing product categories, branching out into emerging sectors or niche markets can offer new growth opportunities. By looking at underperforming areas with potential, businesses can increase their market share and reduce reliance on just a few dominant categories.
#
# Strengthen Risk Management: It’s important for companies to assess how much they depend on imports in certain categories and explore alternatives to enhance supply chain resilience. This proactive approach can help mitigate risks and ensure smoother operations.

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import dataset
df = pd.read_csv('C:\\Users\\Hp\\Downloads\\Imports_Exports_Dataset (1).csv')

# %%
df.head()
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Random Sample from the dataset
df_sample = df.sample(n=3001, random_state = 55023)
df_sample.head()
# Out:
#                              Transaction_ID       Country  Product  \
# 7575   99298f6d-4630-493f-a215-dba810d36228  Burkina Faso  hundred
# 7898   051dcf24-03f2-4d3e-b8e6-d3bddd298a57   Isle of Man    style
# 11534  5f0d9b14-56b3-4949-b0df-10cdfe78bd54     Argentina  subject
# 10117  db46dd88-18d9-429f-825b-7c85c476714f       Armenia    write
# 8867   e1c87ff9-ee9a-40c7-9b9a-3bbda7542293      Barbados   region
#
#       Import_Export  Quantity    Value        Date     Category  \
# 7575         Export      1052  3084.02  02-08-2024     Clothing
# 7898         Import      6333  8201.51  27-08-2022  Electronics
# 11534        Export      7125  6643.86  18-06-2022    Machinery
# 10117        Export      9757   852.29  20-08-2022     Clothing
# 8867         Export      1156  1688.27  11-01-2024         Toys
#
#                 Port  Customs_Code   Weight Shipping_Method  \
# 7575      Greeneland        203424  2619.91            Land
# ...

# %%
# Dimensions of the data
dimensions = df_sample.shape
print('No. of rows in the data are:',dimensions[0])
print('No. of columns in the data are:',dimensions[1])
# Out:
# No. of rows in the data are: 3001
# No. of columns in the data are: 16

# %%
# Count the number of Import and Export transactions
transaction_counts = df_sample['Import_Export'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(transaction_counts, labels=transaction_counts.index, autopct='%1.1f%%', startangle=90, colors=['purple', 'pink'])
plt.title('Percentage of Import and Export Transactions')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Group the data by Category and Import_Export, then count the number of transactions
category_transaction_counts = df_sample.groupby(['Category', 'Import_Export']).size().unstack()

# Plot a stacked bar chart
category_transaction_counts.plot(kind='bar', stacked=True, figsize=(8, 6), color=['purple', 'pink'])

# Add labels and title
plt.title('Transactions by Category (Stacked by Import/Export)')
plt.xlabel('Category')
plt.ylabel('Number of Transactions')
plt.legend(title='Transaction Type')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Count the occurrences of each payment mode
payment_mode_counts = df_sample['Payment_Terms'].value_counts()

# Plot a horizontal bar chart
plt.figure(figsize=(8, 6))
payment_mode_counts.plot(kind='barh')

# Add labels and title
plt.title('Most Preferred Payment Modes')
plt.xlabel('Number of Transactions')
plt.ylabel('Payment Mode')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Convert 'Date' column to datetime format
df_sample['Date'] = pd.to_datetime(df_sample['Date'], format='%d-%m-%Y')

# Extract month from the date
df_sample['Month'] = df_sample['Date'].dt.month

# Group by month and Import_Export, then calculate the average transaction value
monthly_avg_value = df_sample.groupby(['Month', 'Import_Export'])['Value'].mean().unstack()

# Plot the line graph
plt.figure(figsize=(8, 6))

# Plot each import and export line
for column in monthly_avg_value.columns:
    plt.plot(monthly_avg_value.index, monthly_avg_value[column], marker='o', label=column)

# Add labels and title
plt.title('Average Value of Transactions by Month')
plt.xlabel('Month')
plt.ylabel('Average Transaction Value')
plt.grid(True)
plt.legend(title='Transaction Type')  # Add legend to distinguish between imports and exports

# Show the plot
plt.tight_layout()
plt.show()
